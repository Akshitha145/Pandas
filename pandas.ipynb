# %% [markdown]
# <a href="https://colab.research.google.com/github/Akshitha145/Pandas/blob/main/pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df = pd.read_excel("/content/empdata.csv")

# %%
df.head()
# Out:
#    Empid           Ename    Salary                  DOJ
# 0   1001          Ganesh   1000.00  2000-10-10 00:00:00
# 1   1002            Anil  23000.50            3/20/2002
# 2   1003          Gaurav       NaN  2002-03-03 00:00:00
# 3   1004    Hema Chandra  16500.50  2000-10-09 00:00:00
# 4   1005  Laxmi Prasanna  12000.75  2000-08-10 00:00:00

# %%
df.tail()
# Out:
#    Empid           Ename    Salary                  DOJ
# 1   1002            Anil  23000.50            3/20/2002
# 2   1003          Gaurav       NaN  2002-03-03 00:00:00
# 3   1004    Hema Chandra  16500.50  2000-10-09 00:00:00
# 4   1005  Laxmi Prasanna  12000.75  2000-08-10 00:00:00
# 5   1006          Anant    9999.99  1999-09-09 00:00:00

# %%
df.tail(2)
# Out:
#    Empid           Ename    Salary                  DOJ
# 4   1005  Laxmi Prasanna  12000.75  2000-08-10 00:00:00
# 5   1006          Anant    9999.99  1999-09-09 00:00:00

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6 entries, 0 to 5
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Empid   6 non-null      int64
#  1   Ename   6 non-null      object
#  2   Salary  5 non-null      float64
#  3   DOJ     6 non-null      object
# dtypes: float64(1), int64(1), object(2)
# memory usage: 320.0+ bytes

# %%
df.describe()
# Out:
#              Empid        Salary
# count     6.000000      5.000000
# mean   1003.500000  12500.348000
# std       1.870829   8139.622234
# min    1001.000000   1000.000000
# 25%    1002.250000   9999.990000
# 50%    1003.500000  12000.750000
# 75%    1004.750000  16500.500000
# max    1006.000000  23000.500000

# %%
df.shape
# Out:
# (6, 4)

# %%
df.columns
# Out:
# Index(['Empid', 'Ename', 'Salary', 'DOJ'], dtype='object')

# %%
df.Empid
# Out:
# 0    1001
# 1    1002
# 2    1003
# 3    1004
# 4    1005
# 5    1006
# Name: Empid, dtype: int64

# %%
df[['Empid','Ename']]
# Out:
#    Empid           Ename
# 0   1001          Ganesh
# 1   1002            Anil
# 2   1003          Gaurav
# 3   1004    Hema Chandra
# 4   1005  Laxmi Prasanna
# 5   1006          Anant

# %%
df.columns = [i.upper() for i in df]
print(df.columns)
# Out:
# Index(['EMPID', 'ENAME', 'SALARY', 'DOJ'], dtype='object')

# %%
df.isnull().sum()
# Out:
# EMPID     0
# ENAME     0
# SALARY    1
# DOJ       0
# dtype: int64

# %%
print(df.isnull())
print('the no.of nulls in each column is \n',df.isnull().sum())
df.dropna(axis = 1,inplace = False)
# Out:
#    EMPID  ENAME  SALARY    DOJ
# 0  False  False   False  False
# 1  False  False   False  False
# 2  False  False    True  False
# 3  False  False   False  False
# 4  False  False   False  False
# 5  False  False   False  False
# the no.of nulls in each column is
#  EMPID     0
# ENAME     0
# SALARY    1
# DOJ       0
# dtype: int64
#    EMPID           ENAME                  DOJ
# 0   1001          Ganesh  2000-10-10 00:00:00
# 1   1002            Anil            3/20/2002
# 2   1003          Gaurav  2002-03-03 00:00:00
# 3   1004    Hema Chandra  2000-10-09 00:00:00
# 4   1005  Laxmi Prasanna  2000-08-10 00:00:00
# 5   1006          Anant   1999-09-09 00:00:00

# %%
print ('Highest salary is',df['SALARY'].max())
print ('Lowest salary is',df['SALARY'].min())
# Out:
# Highest salary is 23000.5
# Lowest salary is 1000.0

# %%
df[df.SALARY > 20000]
# Out:
#    EMPID ENAME   SALARY        DOJ
# 1   1002  Anil  23000.5  3/20/2002

# %%
df[['EMPID','ENAME']] [df.SALARY == df.SALARY.max()]
# Out:
#    EMPID ENAME
# 1   1002  Anil
